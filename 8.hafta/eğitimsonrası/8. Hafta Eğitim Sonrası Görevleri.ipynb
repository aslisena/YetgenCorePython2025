# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def vki_hesapla(kilo, boy):
    return kilo / (boy ** 2)

def vki_siniflandir(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki <= 24.9:
        return "Normal kilolu"
    elif 25 <= vki <= 29.9:
        return "Fazla kilolu"
    elif 30 <= vki <= 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

def veri_giris_platformu():
    try:
        giris_sayisi = int(input("Kaç kişi için veri girişi yapacaksınız? "))
    except ValueError:
        print("Lütfen geçerli bir sayı girin.")
        return

    with open("veriler.txt", "w", encoding="utf-8") as dosya:
        for i in range(giris_sayisi):
            print(f"\n{i+1}. Kişi Bilgileri:")
            ad_soyad = input("İsim Soyisim: ")
            try:
                yas = int(input("Yaş: "))
                boy = float(input("Boy (metre): "))
                kilo = float(input("Kilo (kg): "))
            except ValueError:
                print("Hatalı giriş yapıldı. Sayısal değerler için lütfen sadece rakam kullanın.")
                continue

            vki = vki_hesapla(kilo, boy)
            sinif = vki_siniflandir(vki)

            print(f"VKİ: {vki:.2f} - Sınıf: {sinif}")

            veri = f"{ad_soyad}, Yaş: {yas}, Boy: {boy} m, Kilo: {kilo} kg, VKİ: {vki:.2f}, Sınıf: {sinif}\n"
            dosya.write(veri)

    print("\nTüm veriler 'veriler.txt' dosyasına kaydedildi.")

veri_giris_platformu()
# Out:
# 1. Kişi Bilgileri:
# VKİ: 0.00 - Sınıf: Zayıf
#
# 2. Kişi Bilgileri:
# VKİ: 0.00 - Sınıf: Zayıf
#
# Tüm veriler 'veriler.txt' dosyasına kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import time
from datetime import datetime

meyve_menusu = {
    "ananas": 5,
    "yaban mersini": 10,
    "çilek": 7,
    "mango": 15,
    "ahududu": 12,
    "muz": 3,
    "böğürtlen": 8
}

def menuyu_goster():
    print("\n--- YetBar Menüsü ---")
    for meyve, fiyat in meyve_menusu.items():
        print(f"{meyve.title()}: {fiyat} TL")
    print()

def siparis_al():
    menuyu_goster()
    siparis = input("Sipariş vermek istediğiniz meyveleri virgülle ayırarak girin: ")
    siparis_listesi = [meyve.strip().lower() for meyve in siparis.split(",")]

    toplam_fiyat = 0
    secilen_meyveler = []

    for meyve in siparis_listesi:
        if meyve in meyve_menusu:
            toplam_fiyat += meyve_menusu[meyve]
            secilen_meyveler.append(meyve)
        else:
            print(f"{meyve} menüde bulunmamaktadır.")
    
    return toplam_fiyat, secilen_meyveler

def log_kaydet(meyveler, fiyat):
    with open("smoothie_kayitlari.txt", "a", encoding="utf-8") as dosya:
        zaman = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        satir = f"{zaman} | Sipariş: {', '.join(meyveler)} | Toplam Fiyat: {fiyat} TL\n"
        dosya.write(satir)

def odeme_yap(toplam_fiyat, secilen_meyveler):
    print(f"Toplam fiyat: {toplam_fiyat} TL")
    odeme = input("Ödeme yapmak için 'Evet' yazın: ")
    if odeme.lower() == "evet":
        print("Ödeme alındı. Siparişiniz hazırlanıyor... Teşekkür ederiz.")
        time.sleep(2)
        print("Siparişiniz hazır. Afiyet olsun.\n")
        log_kaydet(secilen_meyveler, toplam_fiyat)
    else:
        print("Ödeme alınamadı. Lütfen tekrar deneyin.\n")

def ana_menu():
    while True:
        print("=== YetBar Smoothie Bank ===")
        print("1. Menüyü Görüntüle")
        print("2. Sipariş Ver")
        print("3. Çıkış")

        secim = input("Seçiminizi yapın (1/2/3): ")
        if secim == "1":
            menuyu_goster()
        elif secim == "2":
            toplam_fiyat, secilen_meyveler = siparis_al()
            odeme_yap(toplam_fiyat, secilen_meyveler)
        elif secim == "3":
            print("Çıkış yapılıyor... İyi günler!")
            break
        else:
            print("Geçersiz seçim. Lütfen tekrar deneyin.\n")

ana_menu()
# Out:
# === YetBar Smoothie Bank ===
# 1. Menüyü Görüntüle
# 2. Sipariş Ver
# 3. Çıkış
#
# --- YetBar Menüsü ---
# Ananas: 5 TL
# Yaban Mersini: 10 TL
# Çilek: 7 TL
# Mango: 15 TL
# Ahududu: 12 TL
# Muz: 3 TL
# Böğürtlen: 8 TL
#
# Toplam fiyat: 24 TL
# Ödeme alındı. Siparişiniz hazırlanıyor... Teşekkür ederiz.
# Siparişiniz hazır. Afiyet olsun.
#
# === YetBar Smoothie Bank ===
# 1. Menüyü Görüntüle
# 2. Sipariş Ver
# 3. Çıkış
# Çıkış yapılıyor... İyi günler!
